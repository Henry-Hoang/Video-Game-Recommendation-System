# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %%
import sys
import os
import logging
import papermill as pm
import scrapbook as sb
from tempfile import TemporaryDirectory
import pandas as pd
import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.utils.timer import Timer
from recommenders.utils.constants import SEED
from recommenders.models.deeprec.deeprec_utils import prepare_hparams

from recommenders.datasets.amazon_reviews import download_and_extract, data_preprocessing
from recommenders.datasets.download_utils import maybe_download

from recommenders.models.deeprec.models.sequential.sli_rec import SLI_RECModel as SeqModel
from recommenders.models.deeprec.io.sequential_iterator import SequentialIterator

print("System version: {}".format(sys.version))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)]
# Tensorflow version: 1.15.0

# %% [markdown]
# # 1. Input Data Format
# The input data contains 8 columns, i.e.,   `<label> <user_id> <item_id> <category_id> <timestamp> <history_item_ids> <history_cateory_ids> <hitory_timestamp>`  columns are seperated by `"\t"`.  item_id and category_id denote the target item and category, which means that for this instance, we want to guess whether user user_id will interact with item_id at timestamp. `<history_*>` columns record the user behavior list up to `<timestamp>`, elements are separated by commas.  `<label>` is a binary value with 1 for positive instances and 0 for negative instances.  One example for an instance is:
#
# `1	523120	14414	3	1612282953577	14330,14135,5877	3,0,8	1611878652251,1611935700202,1612166343656`
#
# In data preprocessing stage, we have a script to generate some ID mapping dictionaries, so user_id, item_id and category_id will be mapped into interager index starting from 1. And you need to tell the input iterator where is the ID mapping files are. (For example, in the next section, we have some mapping files like user_vocab, item_vocab, and cate_vocab).  The data preprocessing script is at [recommenders/dataset/amazon_reviews.py](../nhat_hoang/recommenders/datasets/amazon_reviews.py). Note that ID vocabulary only creates from the train_file, so the new IDs in valid_file or test_file will be regarded as unknown IDs and assigned with a defualt 0 index.
#
# We use Softmax to the loss function. In training and evalution stage, we group 1 positive instance with num_ngs negative instances. Pair-wise ranking can be regarded as a special case of Softmax ranking, where num_ngs is set to 1.
#
# More specifically,  for training and evalation, you need to organize the data file such that each one positive instance is followd by num_ngs negative instances. Our program will take 1+num_ngs lines as a unit for Softmax calculation. num_ngs is a parameter you need to pass to the `prepare_hparams`, `fit` and `run_eval` function. `train_num_ngs` in `prepare_hparams` denotes the number of negative instances for training, where a recommended number is 4. `valid_num_ngs` and `num_ngs` in `fit` and `run_eval` denote the number in evalution. In evaluation, the model calculates metrics among the 1+num_ngs instances. For the `predict` function, since we only need to calcuate a socre for each individual instance, there is no need for num_ngs setting.  More details and examples will be provided in the following sections.

# %%
yaml_file = '../nhat_hoang/recommenders/models/deeprec/config/sli_rec.yaml'

# %%
EPOCHS = 10
BATCH_SIZE = 400
RANDOM_SEED = SEED  # Set None for non-deterministic result

data_path = os.path.join("..", "nhat_hoang", "test_slirec", "sampled_dataset2")

# %%
# for test
train_file = os.path.join(data_path, r'train_data')
valid_file = os.path.join(data_path, r'valid_data')
test_file = os.path.join(data_path, r'test_data')
user_vocab = os.path.join(data_path, r'user_vocab.pkl')
item_vocab = os.path.join(data_path, r'item_vocab.pkl')
cate_vocab = os.path.join(data_path, r'category_vocab.pkl')
output_file = os.path.join(data_path, r'output.txt')

train_num_ngs = 4 # number of negative instances with a positive instance for training
valid_num_ngs = 4 # number of negative instances with a positive instance for validation
test_num_ngs = 9 # number of negative instances with a positive instance for testing
sample_rate = 0.01 # sample a small item set for training and testing here for fast example; otherwise, sample_rate=1

if not os.path.exists(train_file):
    data_preprocessing(train_file, valid_file, test_file, user_vocab, item_vocab, cate_vocab,
                       sample_rate=sample_rate, valid_num_ngs=valid_num_ngs, test_num_ngs=test_num_ngs)

# %% [markdown]
# ### 1.1 Prepare hyper-parameters
#
# `prepare_hparams()` will create a full set of hyper-parameters for model training, such as learning rate, feature number, and dropout ratio. We can put those parameters in a yaml file (a complete list of parameters can be found under our config folder) , or pass parameters as the function's parameters (which will overwrite yaml settings).
#
# Parameters hints:
# need_sample controls whether to perform dynamic negative sampling in mini-batch. train_num_ngs indicates how many negative instances followed by one positive instances.
# Examples:
# - `need_sample=True` and `train_num_ngs=4`: There are only positive instances in your training file. Our model will dynamically sample 4 negative instances for each positive instances in mini-batch. Note that if `need_sample is` set to True, `train_num_ngs` should be greater than zero.
# - `need_sample=False` and `train_num_ngs=4`: In your training file, each one positive line is followed by 4 negative lines. Note that if `need_sample` is set to False, you must provide a traiing file with negative instances, and `train_num_ngs` should match the number of negative number in training file.

# %%
hparams = prepare_hparams(yaml_file, 
                          embed_l2=0., 
                          layer_l2=0., 
                          learning_rate=0.001,  # set to 0.01 if batch normalization is disable
                          epochs=EPOCHS,
                          batch_size=BATCH_SIZE,
                          show_step=20,
                          MODEL_DIR=os.path.join(data_path, "model/"),
                          SUMMARIES_DIR=os.path.join(data_path, "summary/"),
                          user_vocab=user_vocab,
                          item_vocab=item_vocab,
                          cate_vocab=cate_vocab,
                          need_sample=True,
                          train_num_ngs=train_num_ngs, # provides the number of negative instances for each positive instance for loss computation.
)

# %% [markdown]
# ### 1.2 Create data loader
# Designate a data iterator for the model. All our sequential models use SequentialIterator. data format is introduced aboved.
#
#
# Validation and testing data are files after negative sampling offline with the number of <num_ngs> and <test_num_ngs>.

# %%
input_creator = SequentialIterator

# %% [markdown]
# # 2. Create Model

# %%
model = SeqModel(hparams, input_creator, seed=RANDOM_SEED)

# if don't want to train a new model from scratch, load a pre-trained model like this: 
# model.load_model(os.path.join(hparams.MODEL_DIR, "best_model"))

# %% [markdown]
# Performance before training

# %%
model.run_eval(test_file, num_ngs=test_num_ngs)
# Out:
# {'auc': 0.5513,
#  'logloss': 0.6931,
#  'mean_mrr': 0.2218,
#  'group_auc': 0.5499,
#  'ndcg@1': 0.0083,
#  'ndcg@3': 0.1026,
#  'ndcg@5': 0.2685,
#  'hit@1': 0.0083,
#  'hit@3': 0.1752,
#  'hit@5': 0.587}

# %% [markdown]
# AUC=0.5 is a state of random guess. We can see that before training, the model behaves like random guessing.
#
# ### Train model

# %%
with Timer() as train_time:
    model = model.fit(train_file, valid_file, valid_num_ngs=valid_num_ngs) 

# valid_num_ngs is the number of negative lines after each positive line in your valid_file 
# we will evaluate the performance of model on valid_file every epoch
print('Time cost for training is {0:.2f} mins'.format(train_time.interval/60.0))
# Out:
# step 20 , total_loss: 0.8534, data_loss: 0.8534
# step 40 , total_loss: 0.6505, data_loss: 0.6505
# step 60 , total_loss: 0.6012, data_loss: 0.6012
# step 80 , total_loss: 0.5656, data_loss: 0.5656
# step 100 , total_loss: 0.3015, data_loss: 0.3015
# step 120 , total_loss: 0.3988, data_loss: 0.3988
# step 140 , total_loss: 0.3420, data_loss: 0.3420
# step 160 , total_loss: 0.3821, data_loss: 0.3821
# step 180 , total_loss: 0.4811, data_loss: 0.4811
# step 200 , total_loss: 0.3865, data_loss: 0.3865
# step 220 , total_loss: 0.4154, data_loss: 0.4154
# step 240 , total_loss: 0.3656, data_loss: 0.3656
# step 260 , total_loss: 0.3527, data_loss: 0.3527
# step 280 , total_loss: 0.4438, data_loss: 0.4438
# step 300 , total_loss: 0.3061, data_loss: 0.3061
# step 320 , total_loss: 0.4561, data_loss: 0.4561
# step 340 , total_loss: 0.4508, data_loss: 0.4508
# step 360 , total_loss: 0.5473, data_loss: 0.5473
# step 380 , total_loss: 0.4194, data_loss: 0.4194
# step 400 , total_loss: 0.3325, data_loss: 0.3325
# step 420 , total_loss: 0.3655, data_loss: 0.3655
# step 440 , total_loss: 0.3120, data_loss: 0.3120
# step 460 , total_loss: 0.3464, data_loss: 0.3464
# step 480 , total_loss: 0.3796, data_loss: 0.3796
# step 500 , total_loss: 0.3895, data_loss: 0.3895
# step 520 , total_loss: 0.4111, data_loss: 0.4111
# step 540 , total_loss: 0.3345, data_loss: 0.3345
# step 560 , total_loss: 0.3820, data_loss: 0.3820
# step 580 , total_loss: 0.3718, data_loss: 0.3718
# step 600 , total_loss: 0.4117, data_loss: 0.4117
# step 620 , total_loss: 0.4636, data_loss: 0.4636
# step 640 , total_loss: 0.3690, data_loss: 0.3690
# step 660 , total_loss: 0.4116, data_loss: 0.4116
# step 680 , total_loss: 0.3298, data_loss: 0.3298
# step 700 , total_loss: 0.4908, data_loss: 0.4908
# step 720 , total_loss: 0.3581, data_loss: 0.3581
# step 740 , total_loss: 0.2725, data_loss: 0.2725
# step 760 , total_loss: 0.3756, data_loss: 0.3756
# step 780 , total_loss: 0.3779, data_loss: 0.3779
# step 800 , total_loss: 0.3214, data_loss: 0.3214
# step 820 , total_loss: 0.3263, data_loss: 0.3263
# step 840 , total_loss: 0.4023, data_loss: 0.4023
# step 860 , total_loss: 0.3189, data_loss: 0.3189
# step 880 , total_loss: 0.3647, data_loss: 0.3647
# step 900 , total_loss: 0.4229, data_loss: 0.4229
# step 920 , total_loss: 0.3715, data_loss: 0.3715
# step 940 , total_loss: 0.4284, data_loss: 0.4284
# step 960 , total_loss: 0.3536, data_loss: 0.3536
# step 980 , total_loss: 0.2610, data_loss: 0.2610
# step 1000 , total_loss: 0.4422, data_loss: 0.4422
# eval valid at epoch 7: auc:0.8497,logloss:0.685,mean_mrr:0.572,group_auc:0.8265,ndcg@1:0.2041,ndcg@3:0.6626,ndcg@5:0.6824,hit@1:0.2041,hit@3:0.9527,hit@5:1.0
# step 20 , total_loss: 0.3163, data_loss: 0.3163
# step 40 , total_loss: 0.2592, data_loss: 0.2592
# step 60 , total_loss: 0.2868, data_loss: 0.2868
# step 80 , total_loss: 0.2834, data_loss: 0.2834
# step 100 , total_loss: 0.2892, data_loss: 0.2892
# step 120 , total_loss: 0.3053, data_loss: 0.3053
# step 140 , total_loss: 0.2410, data_loss: 0.2410
# step 160 , total_loss: 0.2899, data_loss: 0.2899
# step 180 , total_loss: 0.3343, data_loss: 0.3343
# step 200 , total_loss: 0.2971, data_loss: 0.2971
# step 220 , total_loss: 0.3265, data_loss: 0.3265
# step 240 , total_loss: 0.3522, data_loss: 0.3522
# step 260 , total_loss: 0.2777, data_loss: 0.2777
# step 280 , total_loss: 0.2535, data_loss: 0.2535
# step 300 , total_loss: 0.2488, data_loss: 0.2488
# step 320 , total_loss: 0.2958, data_loss: 0.2958
# step 340 , total_loss: 0.2432, data_loss: 0.2432
# step 360 , total_loss: 0.2739, data_loss: 0.2739
# step 380 , total_loss: 0.4022, data_loss: 0.4022
# step 400 , total_loss: 0.3094, data_loss: 0.3094
# step 420 , total_loss: 0.2750, data_loss: 0.2750
# step 440 , total_loss: 0.3284, data_loss: 0.3284
# step 460 , total_loss: 0.3042, data_loss: 0.3042
# step 480 , total_loss: 0.2795, data_loss: 0.2795
# step 500 , total_loss: 0.2634, data_loss: 0.2634
# step 520 , total_loss: 0.3550, data_loss: 0.3550
# step 540 , total_loss: 0.2441, data_loss: 0.2441
# step 560 , total_loss: 0.2617, data_loss: 0.2617
# step 580 , total_loss: 0.2698, data_loss: 0.2698
# step 600 , total_loss: 0.3819, data_loss: 0.3819
# step 620 , total_loss: 0.3718, data_loss: 0.3718
# step 640 , total_loss: 0.2578, data_loss: 0.2578
# step 660 , total_loss: 0.3007, data_loss: 0.3007
# step 680 , total_loss: 0.2817, data_loss: 0.2817
# step 700 , total_loss: 0.2970, data_loss: 0.2970
# step 720 , total_loss: 0.2388, data_loss: 0.2388
# step 740 , total_loss: 0.2672, data_loss: 0.2672
# step 760 , total_loss: 0.2874, data_loss: 0.2874
# step 780 , total_loss: 0.3314, data_loss: 0.3314
# step 800 , total_loss: 0.3910, data_loss: 0.3910
# step 820 , total_loss: 0.2585, data_loss: 0.2585
# step 840 , total_loss: 0.2456, data_loss: 0.2456
# step 860 , total_loss: 0.2740, data_loss: 0.2740
# step 880 , total_loss: 0.2279, data_loss: 0.2279
# step 900 , total_loss: 0.2929, data_loss: 0.2929
# step 920 , total_loss: 0.3094, data_loss: 0.3094
# step 940 , total_loss: 0.3486, data_loss: 0.3486
# step 960 , total_loss: 0.2286, data_loss: 0.2286
# step 980 , total_loss: 0.3856, data_loss: 0.3856
# step 1000 , total_loss: 0.2530, data_loss: 0.2530
# step 1020 , total_loss: 0.3132, data_loss: 0.3132
# step 1040 , total_loss: 0.3925, data_loss: 0.3925
# step 1060 , total_loss: 0.2796, data_loss: 0.2796
# step 1080 , total_loss: 0.3014, data_loss: 0.3014
# step 1100 , total_loss: 0.2831, data_loss: 0.2831
# step 1120 , total_loss: 0.3117, data_loss: 0.3117
# step 1140 , total_loss: 0.2925, data_loss: 0.2925
# step 1160 , total_loss: 0.3459, data_loss: 0.3459
# step 1180 , total_loss: 0.3249, data_loss: 0.3249
# step 1200 , total_loss: 0.2269, data_loss: 0.2269
# step 1220 , total_loss: 0.2535, data_loss: 0.2535
# step 1240 , total_loss: 0.3124, data_loss: 0.3124
# step 1260 , total_loss: 0.3233, data_loss: 0.3233
# step 1280 , total_loss: 0.3331, data_loss: 0.3331
# step 1300 , total_loss: 0.3591, data_loss: 0.3591
# step 1320 , total_loss: 0.2517, data_loss: 0.2517
# step 1340 , total_loss: 0.2724, data_loss: 0.2724
# step 1360 , total_loss: 0.2641, data_loss: 0.2641
# step 1380 , total_loss: 0.3189, data_loss: 0.3189
# step 1400 , total_loss: 0.2667, data_loss: 0.2667
# step 1420 , total_loss: 0.2939, data_loss: 0.2939
# step 1440 , total_loss: 0.2792, data_loss: 0.2792
# step 1460 , total_loss: 0.3762, data_loss: 0.3762
# step 1480 , total_loss: 0.3210, data_loss: 0.3210
# step 1500 , total_loss: 0.2787, data_loss: 0.2787
# step 1520 , total_loss: 0.2070, data_loss: 0.2070
# step 1540 , total_loss: 0.2745, data_loss: 0.2745
# step 1560 , total_loss: 0.3136, data_loss: 0.3136
# step 1580 , total_loss: 0.2885, data_loss: 0.2885
# step 1600 , total_loss: 0.3250, data_loss: 0.3250
# step 1620 , total_loss: 0.2601, data_loss: 0.2601
# eval valid at epoch 8: auc:0.8443,logloss:0.6838,mean_mrr:0.5696,group_auc:0.8247,ndcg@1:0.2002,ndcg@3:0.6605,ndcg@5:0.6806,hit@1:0.2002,hit@3:0.952,hit@5:1.0
# step 20 , total_loss: 0.2820, data_loss: 0.2820
# step 40 , total_loss: 0.3008, data_loss: 0.3008
# step 60 , total_loss: 0.2969, data_loss: 0.2969
# step 80 , total_loss: 0.2660, data_loss: 0.2660
# step 100 , total_loss: 0.3511, data_loss: 0.3511
# step 120 , total_loss: 0.2716, data_loss: 0.2716
# step 140 , total_loss: 0.3517, data_loss: 0.3517
# step 160 , total_loss: 0.3484, data_loss: 0.3484
# step 180 , total_loss: 0.4512, data_loss: 0.4512
# step 200 , total_loss: 0.3554, data_loss: 0.3554
# step 220 , total_loss: 0.3713, data_loss: 0.3713
# step 240 , total_loss: 0.2355, data_loss: 0.2355
# step 260 , total_loss: 0.3097, data_loss: 0.3097
# step 280 , total_loss: 0.2518, data_loss: 0.2518
# step 300 , total_loss: 0.2913, data_loss: 0.2913
# step 320 , total_loss: 0.3048, data_loss: 0.3048
# step 340 , total_loss: 0.3480, data_loss: 0.3480
# step 360 , total_loss: 0.3588, data_loss: 0.3588
# step 380 , total_loss: 0.3467, data_loss: 0.3467
# step 400 , total_loss: 0.2724, data_loss: 0.2724
# step 1500 , total_loss: 0.2731, data_loss: 0.2731
# step 1520 , total_loss: 0.3254, data_loss: 0.3254
# step 1540 , total_loss: 0.3145, data_loss: 0.3145
# step 1560 , total_loss: 0.2213, data_loss: 0.2213
# step 1580 , total_loss: 0.2684, data_loss: 0.2684
# step 1600 , total_loss: 0.2472, data_loss: 0.2472
# step 1620 , total_loss: 0.3637, data_loss: 0.3637
# eval valid at epoch 9: auc:0.8488,logloss:0.7047,mean_mrr:0.5723,group_auc:0.8268,ndcg@1:0.2046,ndcg@3:0.6629,ndcg@5:0.6827,hit@1:0.2046,hit@3:0.9529,hit@5:1.0
# step 20 , total_loss: 0.2640, data_loss: 0.2640
# step 40 , total_loss: 0.3478, data_loss: 0.3478
# step 60 , total_loss: 0.3126, data_loss: 0.3126
# step 80 , total_loss: 0.2193, data_loss: 0.2193
# step 100 , total_loss: 0.2555, data_loss: 0.2555
# step 120 , total_loss: 0.3023, data_loss: 0.3023
# step 140 , total_loss: 0.2913, data_loss: 0.2913
# step 160 , total_loss: 0.2928, data_loss: 0.2928
# step 180 , total_loss: 0.3247, data_loss: 0.3247
# step 200 , total_loss: 0.3654, data_loss: 0.3654
# step 220 , total_loss: 0.3269, data_loss: 0.3269
# step 240 , total_loss: 0.2683, data_loss: 0.2683
# step 260 , total_loss: 0.4075, data_loss: 0.4075
# step 280 , total_loss: 0.3274, data_loss: 0.3274
# step 300 , total_loss: 0.2728, data_loss: 0.2728
# step 320 , total_loss: 0.2594, data_loss: 0.2594
# step 340 , total_loss: 0.3315, data_loss: 0.3315
# step 360 , total_loss: 0.2304, data_loss: 0.2304
# step 380 , total_loss: 0.2918, data_loss: 0.2918
# step 400 , total_loss: 0.4570, data_loss: 0.4570
# step 420 , total_loss: 0.3357, data_loss: 0.3357
# step 440 , total_loss: 0.2278, data_loss: 0.2278
# step 460 , total_loss: 0.3151, data_loss: 0.3151
# step 480 , total_loss: 0.2329, data_loss: 0.2329
# step 500 , total_loss: 0.3311, data_loss: 0.3311
# step 520 , total_loss: 0.3139, data_loss: 0.3139
# step 540 , total_loss: 0.3065, data_loss: 0.3065
# step 560 , total_loss: 0.3542, data_loss: 0.3542
# step 580 , total_loss: 0.2628, data_loss: 0.2628
# step 600 , total_loss: 0.3121, data_loss: 0.3121
# step 620 , total_loss: 0.2783, data_loss: 0.2783
# step 640 , total_loss: 0.2468, data_loss: 0.2468
# step 660 , total_loss: 0.1848, data_loss: 0.1848
# step 680 , total_loss: 0.3123, data_loss: 0.3123
# step 700 , total_loss: 0.2895, data_loss: 0.2895
# step 720 , total_loss: 0.3131, data_loss: 0.3131
# step 740 , total_loss: 0.2847, data_loss: 0.2847
# step 760 , total_loss: 0.3258, data_loss: 0.3258
# step 780 , total_loss: 0.3077, data_loss: 0.3077
# step 800 , total_loss: 0.3180, data_loss: 0.3180
# step 820 , total_loss: 0.3002, data_loss: 0.3002
# step 840 , total_loss: 0.3356, data_loss: 0.3356
# step 860 , total_loss: 0.2708, data_loss: 0.2708
# step 880 , total_loss: 0.2645, data_loss: 0.2645
# step 900 , total_loss: 0.3050, data_loss: 0.3050
# step 920 , total_loss: 0.3064, data_loss: 0.3064
# step 940 , total_loss: 0.2619, data_loss: 0.2619
# step 960 , total_loss: 0.3124, data_loss: 0.3124
# step 980 , total_loss: 0.2647, data_loss: 0.2647
# step 1000 , total_loss: 0.3429, data_loss: 0.3429
# step 1020 , total_loss: 0.2943, data_loss: 0.2943
# step 1040 , total_loss: 0.3081, data_loss: 0.3081
# step 1060 , total_loss: 0.2765, data_loss: 0.2765
# step 1080 , total_loss: 0.3143, data_loss: 0.3143
# step 1100 , total_loss: 0.2694, data_loss: 0.2694
# step 1120 , total_loss: 0.2590, data_loss: 0.2590
# step 1140 , total_loss: 0.2150, data_loss: 0.2150
# step 1160 , total_loss: 0.3216, data_loss: 0.3216
# step 1180 , total_loss: 0.3069, data_loss: 0.3069
# step 1200 , total_loss: 0.3248, data_loss: 0.3248
# step 1220 , total_loss: 0.2722, data_loss: 0.2722
# step 1240 , total_loss: 0.3538, data_loss: 0.3538
# step 1260 , total_loss: 0.3407, data_loss: 0.3407
# step 1280 , total_loss: 0.2548, data_loss: 0.2548
# step 1300 , total_loss: 0.3353, data_loss: 0.3353
# step 1320 , total_loss: 0.2559, data_loss: 0.2559
# step 1340 , total_loss: 0.2962, data_loss: 0.2962
# step 1360 , total_loss: 0.3079, data_loss: 0.3079
# step 1380 , total_loss: 0.3409, data_loss: 0.3409
# step 1400 , total_loss: 0.2448, data_loss: 0.2448
# step 1420 , total_loss: 0.2968, data_loss: 0.2968
# step 1440 , total_loss: 0.3800, data_loss: 0.3800
# step 1460 , total_loss: 0.2982, data_loss: 0.2982
# step 1480 , total_loss: 0.2868, data_loss: 0.2868
# step 1500 , total_loss: 0.2601, data_loss: 0.2601
# step 1520 , total_loss: 0.2712, data_loss: 0.2712
# step 1540 , total_loss: 0.3016, data_loss: 0.3016
# step 1560 , total_loss: 0.2732, data_loss: 0.2732
# step 1580 , total_loss: 0.3325, data_loss: 0.3325
# step 1600 , total_loss: 0.3262, data_loss: 0.3262
# step 1620 , total_loss: 0.3408, data_loss: 0.3408
# eval valid at epoch 10: auc:0.8492,logloss:0.6928,mean_mrr:0.5715,group_auc:0.8267,ndcg@1:0.2025,ndcg@3:0.6625,ndcg@5:0.6821,hit@1:0.2025,hit@3:0.9534,hit@5:1.0
# [(1, {'auc': 0.8028, 'logloss': 0.9247, 'mean_mrr': 0.529, 'group_auc': 0.7813, 'ndcg@1': 0.1517, 'ndcg@3': 0.6129, 'ndcg@5': 0.6497, 'hit@1': 0.1517, 'hit@3': 0.9122, 'hit@5': 1.0}), (2, {'auc': 0.815, 'logloss': 0.7572, 'mean_mrr': 0.5434, 'group_auc': 0.7974, 'ndcg@1': 0.1677, 'ndcg@3': 0.6305, 'ndcg@5': 0.6606, 'hit@1': 0.1677, 'hit@3': 0.928, 'hit@5': 1.0}), (3, {'auc': 0.8321, 'logloss': 0.7331, 'mean_mrr': 0.5583, 'group_auc': 0.8121, 'ndcg@1': 0.1869, 'ndcg@3': 0.6469, 'ndcg@5': 0.672, 'hit@1': 0.1869, 'hit@3': 0.94, 'hit@5': 1.0}), (4, {'auc': 0.8412, 'logloss': 0.7369, 'mean_mrr': 0.5663, 'group_auc': 0.8205, 'ndcg@1': 0.1966, 'ndcg@3': 0.6563, 'ndcg@5': 0.6781, 'hit@1': 0.1966, 'hit@3': 0.9479, 'hit@5': 1.0}), (5, {'auc': 0.8436, 'logloss': 0.6657, 'mean_mrr': 0.5702, 'group_auc': 0.8255, 'ndcg@1': 0.2002, 'ndcg@3': 0.6613, 'ndcg@5': 0.6811, 'hit@1': 0.2002, 'hit@3': 0.9529, 'hit@5': 1.0}), (6, {'auc': 0.8472, 'logloss': 0.6876, 'mean_mrr': 0.5719, 'group_auc': 0.8265, 'ndcg@1': 0.2037, 'ndcg@3': 0.6628, 'ndcg@5': 0.6824, 'hit@1': 0.2037, 'hit@3': 0.9534, 'hit@5': 1.0}), (7, {'auc': 0.8497, 'logloss': 0.685, 'mean_mrr': 0.572, 'group_auc': 0.8265, 'ndcg@1': 0.2041, 'ndcg@3': 0.6626, 'ndcg@5': 0.6824, 'hit@1': 0.2041, 'hit@3': 0.9527, 'hit@5': 1.0}), (8, {'auc': 0.8443, 'logloss': 0.6838, 'mean_mrr': 0.5696, 'group_auc': 0.8247, 'ndcg@1': 0.2002, 'ndcg@3': 0.6605, 'ndcg@5': 0.6806, 'hit@1': 0.2002, 'hit@3': 0.952, 'hit@5': 1.0}), (9, {'auc': 0.8488, 'logloss': 0.7047, 'mean_mrr': 0.5723, 'group_auc': 0.8268, 'ndcg@1': 0.2046, 'ndcg@3': 0.6629, 'ndcg@5': 0.6827, 'hit@1': 0.2046, 'hit@3': 0.9529, 'hit@5': 1.0}), (10, {'auc': 0.8492, 'logloss': 0.6928, 'mean_mrr': 0.5715, 'group_auc': 0.8267, 'ndcg@1': 0.2025, 'ndcg@3': 0.6625, 'ndcg@5': 0.6821, 'hit@1': 0.2025, 'hit@3': 0.9534, 'hit@5': 1.0})]
# best epoch: 9
# Time cost for training is 135.52 mins

# %% [markdown]
# ### Evaluate

# %% [markdown]
# Performance after training

# %%
model.run_eval(test_file, num_ngs=test_num_ngs)
# Out:
# {'auc': 0.8662,
#  'logloss': 0.6888,
#  'mean_mrr': 0.4215,
#  'group_auc': 0.8375,
#  'ndcg@1': 0.0357,
#  'ndcg@3': 0.4709,
#  'ndcg@5': 0.5389,
#  'hit@1': 0.0357,
#  'hit@3': 0.7546,
#  'hit@5': 0.9188}

# %% [markdown]
# Test the model on the test_file extracted from the whole_dataset2

# %%
model.run_eval(os.path.join("..", "nhat_hoang", "test_slirec", "whole_dataset", "test_data"), num_ngs=test_num_ngs)
# Out:
# {'auc': 0.5775,
#  'logloss': 1.4509,
#  'mean_mrr': 0.2483,
#  'group_auc': 0.5764,
#  'ndcg@1': 0.0598,
#  'ndcg@3': 0.1679,
#  'ndcg@5': 0.2032,
#  'hit@1': 0.0598,
#  'hit@3': 0.2412,
#  'hit@5': 0.3281}
